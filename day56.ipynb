# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('/content/Social_Network_Ads.csv')

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
df['Gender'] = df['Gender'].map({'Male': 1, 'Female' : 0})

# %%
df.head(3)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       0   26            43000          0

# %%
X = df.drop('Purchased', axis=1)
y = df['Purchased']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=92)

# %%
tf.random.set_seed(909)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation= 'relu6'),
    tf.keras.layers.Dense(1, activation ='sigmoid')
])

model.compile( loss = tf.keras.losses.BinaryFocalCrossentropy(),
              metrics = ['accuracy'],
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.001))

model.fit(X_train, y_train, epochs=30,verbose = 1, validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.3215 - loss: 2.0763 - val_accuracy: 0.4125 - val_loss: 1.7035
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 1.9335 - val_accuracy: 0.4125 - val_loss: 1.5796
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3215 - loss: 1.7903 - val_accuracy: 0.4125 - val_loss: 1.4553
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.3215 - loss: 1.6467 - val_accuracy: 0.4125 - val_loss: 1.3310
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 1.5033 - val_accuracy: 0.4125 - val_loss: 1.2077
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.3215 - loss: 1.3612 - val_accuracy: 0.4125 - val_loss: 1.0862
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3215 - loss: 1.2217 - val_accuracy: 0.4125 - val_loss: 0.9682
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3215 - loss: 1.0865 - val_accuracy: 0.4125 - val_loss: 0.8550
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3215 - loss: 0.9572 - val_accuracy: 0.4125 - val_loss: 0.7484
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 0.8359 - val_accuracy: 0.4125 - val_loss: 0.6499
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.3215 - loss: 0.7243 - val_accuracy: 0.4125 - val_loss: 0.5610
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.3215 - loss: 0.6238 - val_accuracy: 0.4125 - val_loss: 0.4827
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.3215 - loss: 0.5355 - val_accuracy: 0.4125 - val_loss: 0.4153
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3215 - loss: 0.4595 - val_accuracy: 0.4125 - val_loss: 0.3588
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3215 - loss: 0.3957 - val_accuracy: 0.4125 - val_loss: 0.3126
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 0.3432 - val_accuracy: 0.4125 - val_loss: 0.2756
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.3215 - loss: 0.3009 - val_accuracy: 0.4125 - val_loss: 0.2468
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.3215 - loss: 0.2674 - val_accuracy: 0.4125 - val_loss: 0.2247
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.3215 - loss: 0.2412 - val_accuracy: 0.4125 - val_loss: 0.2081
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.3215 - loss: 0.2210 - val_accuracy: 0.4125 - val_loss: 0.1960
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 0.2055 - val_accuracy: 0.4125 - val_loss: 0.1872
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3215 - loss: 0.1938 - val_accuracy: 0.4125 - val_loss: 0.1809
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.3215 - loss: 0.1849 - val_accuracy: 0.4125 - val_loss: 0.1766
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3215 - loss: 0.1783 - val_accuracy: 0.4125 - val_loss: 0.1738
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.4568 - loss: 0.1733 - val_accuracy: 0.5875 - val_loss: 0.1719
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6785 - loss: 0.1697 - val_accuracy: 0.5875 - val_loss: 0.1708
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.6785 - loss: 0.1669 - val_accuracy: 0.5875 - val_loss: 0.1702
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.6785 - loss: 0.1649 - val_accuracy: 0.5875 - val_loss: 0.1699
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6785 - loss: 0.1634 - val_accuracy: 0.5875 - val_loss: 0.1699
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.6785 - loss: 0.1623 - val_accuracy: 0.5875 - val_loss: 0.1699

# %%
model.evaluate(X_test, y_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5906 - loss: 0.1697
# [0.16994290053844452, 0.5874999761581421]
