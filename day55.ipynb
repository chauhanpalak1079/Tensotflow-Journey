# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('/content/medical_insurance.csv')

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       2772 non-null   int64
#  1   sex       2772 non-null   object
#  2   bmi       2772 non-null   float64
#  3   children  2772 non-null   int64
#  4   smoker    2772 non-null   object
#  5   region    2772 non-null   object
#  6   charges   2772 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 151.7+ KB

# %%
df['sex'] = df['sex'].map({'male' : 1, 'female' : 0})
df['smoker'] = df['smoker'].map({'yes' : 1, 'no' : 0})

# %%
df = pd.get_dummies(df, columns=['region'])

# %%
df.head(3)
# Out:
#    age  sex    bmi  children  smoker     charges  region_northeast  \
# 0   19    0  27.90         0       1  16884.9240             False
# 1   18    1  33.77         1       0   1725.5523             False
# 2   28    1  33.00         3       0   4449.4620             False
#
#    region_northwest  region_southeast  region_southwest
# 0             False             False              True
# 1             False              True             False
# 2             False              True             False

# %%
X = df.drop('charges', axis=1)
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=92)

# %%
tf.random.set_seed(43)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation= 'relu'),
    tf.keras.layers.Dense(1, activation ='relu')
])

model.compile( loss = tf.keras.losses.MeanSquaredLogarithmicError,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.1))

model.fit(X_train, y_train, epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 26.9931
# Epoch 2/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.9426
# Epoch 3/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1.0523
# Epoch 4/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7936
# Epoch 5/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7030
# Epoch 6/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6680
# Epoch 7/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6529
# Epoch 8/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6450
# Epoch 9/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6397
# Epoch 10/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6353
# Epoch 11/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6311
# Epoch 12/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.6269
# Epoch 13/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.6225
# Epoch 14/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6179
# Epoch 15/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6130
# Epoch 16/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6079
# Epoch 17/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.6023
# Epoch 18/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5965
# Epoch 19/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5902
# Epoch 20/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5835
# Epoch 21/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5763
# Epoch 22/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5686
# Epoch 23/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5604
# Epoch 24/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5515
# Epoch 25/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5420
# Epoch 26/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5319
# Epoch 27/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5211
# Epoch 28/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5098
# Epoch 29/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4981
# Epoch 30/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4861
# Epoch 31/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4742
# Epoch 32/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4623
# Epoch 33/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4508
# Epoch 34/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4398
# Epoch 35/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4289
# Epoch 36/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4183
# Epoch 37/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4077
# Epoch 38/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3973
# Epoch 39/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3869
# Epoch 40/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3766
# Epoch 41/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3665
# Epoch 42/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3565
# Epoch 43/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3467
# Epoch 44/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3371
# Epoch 45/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3278
# Epoch 46/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3188
# Epoch 47/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3100
# Epoch 48/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3015
# Epoch 49/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2934
# Epoch 50/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2855
# Epoch 51/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2779
# Epoch 52/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2707
# Epoch 53/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2637
# Epoch 54/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2574
# Epoch 55/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2510
# Epoch 56/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2448
# Epoch 57/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2389
# Epoch 58/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2327
# Epoch 59/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2277
# Epoch 60/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2227
# Epoch 61/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2180
# Epoch 62/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2137
# Epoch 63/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2096
# Epoch 64/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2059
# Epoch 65/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2024
# Epoch 66/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1991
# Epoch 67/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1962
# Epoch 68/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1934
# Epoch 69/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1909
# Epoch 70/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1886
# Epoch 71/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1865
# Epoch 72/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1845
# Epoch 73/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1827
# Epoch 74/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1811
# Epoch 75/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1796
# Epoch 76/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1782
# Epoch 77/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1770
# Epoch 78/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1759
# Epoch 79/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1749
# Epoch 80/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1740
# Epoch 81/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1732
# Epoch 82/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1725
# Epoch 83/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1719
# Epoch 84/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1713
# Epoch 85/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1708
# Epoch 86/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1703
# Epoch 87/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1700
# Epoch 88/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1696
# Epoch 89/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1692
# Epoch 90/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1690
# Epoch 91/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1687
# Epoch 92/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1685
# Epoch 93/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1683
# Epoch 94/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1681
# Epoch 95/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1680
# Epoch 96/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1679
# Epoch 97/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1678
# Epoch 98/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1677
# Epoch 99/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1676
# Epoch 100/100
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1675

# %%
model.evaluate(X_test, y_test)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1641
# 0.14718571305274963
