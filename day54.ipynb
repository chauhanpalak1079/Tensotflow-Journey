# %%
import pandas as pd
import tensorflow as tf

# %%
df = pd.read_csv('/content/Walmart.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6435 entries, 0 to 6434
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         6435 non-null   int64
#  1   Date          6435 non-null   object
#  2   Weekly_Sales  6435 non-null   float64
#  3   Holiday_Flag  6435 non-null   int64
#  4   Temperature   6435 non-null   float64
#  5   Fuel_Price    6435 non-null   float64
#  6   CPI           6435 non-null   float64
#  7   Unemployment  6435 non-null   float64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 402.3+ KB

# %%
df.Date=pd.to_datetime(df.Date, format='%d-%m-%Y')

df['day'] = df.Date.dt.day
df['month'] = df.Date.dt.month
df['year'] = df.Date.dt.year

df.head()
# Out:
#    Store       Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1 2010-02-05    1643690.90             0        42.31       2.572
# 1      1 2010-02-12    1641957.44             1        38.51       2.548
# 2      1 2010-02-19    1611968.17             0        39.93       2.514
# 3      1 2010-02-26    1409727.59             0        46.63       2.561
# 4      1 2010-03-05    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment  day  month  year
# 0  211.096358         8.106    5      2  2010
# 1  211.242170         8.106   12      2  2010
# 2  211.289143         8.106   19      2  2010
# 3  211.319643         8.106   26      2  2010
# 4  211.350143         8.106    5      3  2010

# %%
X = df.drop(['Weekly_Sales', 'Date'], axis=1)
y = df['Weekly_Sales']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=92)

# %%
tf.random.set_seed(43)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation= 'relu'),
    tf.keras.layers.Dense(1, activation ='relu')
])

model.compile( loss = tf.keras.losses.MeanSquaredLogarithmicError,
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.1))

model.fit(X_train, y_train, epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - loss: 14.3743
# Epoch 2/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2.4219
# Epoch 3/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1591
# Epoch 4/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7073
# Epoch 5/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5138
# Epoch 6/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4254
# Epoch 7/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3845
# Epoch 8/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3659
# Epoch 9/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3579
# Epoch 10/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3547
# Epoch 11/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3535
# Epoch 12/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3531
# Epoch 13/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3530
# Epoch 14/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3530
# Epoch 15/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3529
# Epoch 16/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3529
# Epoch 17/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3528
# Epoch 18/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3527
# Epoch 19/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3526
# Epoch 20/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3524
# Epoch 21/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3523
# Epoch 22/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3521
# Epoch 23/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3520
# Epoch 24/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3518
# Epoch 25/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3516
# Epoch 26/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3514
# Epoch 27/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3512
# Epoch 28/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3509
# Epoch 29/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3506
# Epoch 30/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3504
# Epoch 31/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3500
# Epoch 32/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3497
# Epoch 33/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3493
# Epoch 34/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3489
# Epoch 35/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3485
# Epoch 36/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3481
# Epoch 37/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3476
# Epoch 38/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3470
# Epoch 39/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3465
# Epoch 40/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3458
# Epoch 41/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3452
# Epoch 42/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3444
# Epoch 43/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3436
# Epoch 44/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3428
# Epoch 45/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3419
# Epoch 46/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3409
# Epoch 47/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3398
# Epoch 48/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3387
# Epoch 49/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3374
# Epoch 50/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3361
# Epoch 51/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3347
# Epoch 52/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3332
# Epoch 53/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3316
# Epoch 54/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3299
# Epoch 55/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3281
# Epoch 56/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3263
# Epoch 57/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3245
# Epoch 58/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3226
# Epoch 59/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3209
# Epoch 60/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3192
# Epoch 61/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3176
# Epoch 62/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3162
# Epoch 63/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3150
# Epoch 64/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3140
# Epoch 65/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3131
# Epoch 66/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3124
# Epoch 67/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3119
# Epoch 68/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3114
# Epoch 69/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3111
# Epoch 70/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3109
# Epoch 71/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3107
# Epoch 72/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3105
# Epoch 73/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3104
# Epoch 74/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3103
# Epoch 75/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3103
# Epoch 76/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3102
# Epoch 77/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3102
# Epoch 78/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3101
# Epoch 79/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3101
# Epoch 80/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3101
# Epoch 81/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3101
# Epoch 82/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3100
# Epoch 83/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3100
# Epoch 84/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3100
# Epoch 85/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3100
# Epoch 86/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3100
# Epoch 87/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3099
# Epoch 88/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3099
# Epoch 89/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3099
# Epoch 90/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3099
# Epoch 91/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3099
# Epoch 92/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3099
# Epoch 93/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3098
# Epoch 94/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3098
# Epoch 95/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3098
# Epoch 96/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3098
# Epoch 97/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3098
# Epoch 98/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.3098
# Epoch 99/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3098
# Epoch 100/100
# 161/161 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3098

# %%
model.evaluate(X_test, y_test)
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2898
# 0.29932400584220886
