# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/ObesityDataSet.csv')
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS           NObeyesdad
# 0  Public_Transportation        Normal_Weight
# 1  Public_Transportation        Normal_Weight
# 2  Public_Transportation        Normal_Weight
# 3                Walking   Overweight_Level_I
# 4  Public_Transportation  Overweight_Level_II

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
#  12  FAF                             2111 non-null   float64
#  13  TUE                             2111 non-null   float64
#  14  CALC                            2111 non-null   object
#  15  MTRANS                          2111 non-null   object
#  16  NObeyesdad                      2111 non-null   object
# dtypes: float64(8), object(9)
# memory usage: 280.5+ KB

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df['NObeyesdad'] = le.fit_transform(df['NObeyesdad'])
df.head()
# Out:
#    Gender   Age  Height  Weight family_history_with_overweight FAVC  FCVC  \
# 0  Female  21.0    1.62    64.0                            yes   no   2.0
# 1  Female  21.0    1.52    56.0                            yes   no   3.0
# 2    Male  23.0    1.80    77.0                            yes   no   2.0
# 3    Male  27.0    1.80    87.0                             no   no   3.0
# 4    Male  22.0    1.78    89.8                             no   no   2.0
#
#    NCP       CAEC SMOKE  CH2O  SCC  FAF  TUE        CALC  \
# 0  3.0  Sometimes    no   2.0   no  0.0  1.0          no
# 1  3.0  Sometimes   yes   3.0  yes  3.0  0.0   Sometimes
# 2  3.0  Sometimes    no   2.0   no  2.0  1.0  Frequently
# 3  3.0  Sometimes    no   2.0   no  2.0  0.0  Frequently
# 4  1.0  Sometimes    no   2.0   no  0.0  0.0   Sometimes
#
#                   MTRANS  NObeyesdad
# 0  Public_Transportation           1
# 1  Public_Transportation           1
# 2  Public_Transportation           1
# 3                Walking           5
# 4  Public_Transportation           6

# %%
df = pd.get_dummies(df)
df.head()
# Out:
#     Age  Height  Weight  FCVC  NCP  CH2O  FAF  TUE  NObeyesdad  Gender_Female  \
# 0  21.0    1.62    64.0   2.0  3.0   2.0  0.0  1.0           1           True
# 1  21.0    1.52    56.0   3.0  3.0   3.0  3.0  0.0           1           True
# 2  23.0    1.80    77.0   2.0  3.0   2.0  2.0  1.0           1          False
# 3  27.0    1.80    87.0   3.0  3.0   2.0  2.0  0.0           5          False
# 4  22.0    1.78    89.8   2.0  1.0   2.0  0.0  0.0           6          False
#
#    ...  SCC_yes  CALC_Always  CALC_Frequently  CALC_Sometimes  CALC_no  \
# 0  ...    False        False            False           False     True
# 1  ...     True        False            False            True    False
# 2  ...    False        False             True           False    False
# 3  ...    False        False             True           False    False
# 4  ...    False        False            False            True    False
#
#    MTRANS_Automobile  MTRANS_Bike  MTRANS_Motorbike  \
# 0              False        False             False
# 1              False        False             False
# 2              False        False             False
# 3              False        False             False
# 4              False        False             False
#
#    MTRANS_Public_Transportation  MTRANS_Walking
# 0                          True           False
# 1                          True           False
# 2                          True           False
# 3                         False            True
# 4                          True           False
#
# [5 rows x 32 columns]

# %%
X = df.drop('NObeyesdad', axis=1)
y = df['NObeyesdad']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size =0.2, random_state=92)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation= 'relu'),
    tf.keras.layers.Dense(90, activation= 'relu'),
    tf.keras.layers.Dense(80, activation= 'relu'),
    tf.keras.layers.Dense(50, activation= 'relu'),
    tf.keras.layers.Dense(30, activation= 'relu'),
    tf.keras.layers.Dense(10, activation ='relu')
])

model.compile( loss = tf.keras.losses.MeanAbsoluteError(),
              optimizer = tf.keras.optimizers.Adam(learning_rate=0.001),
               metrics = ['mae'])

model.fit(X_train, y_train, epochs=100,verbose = 1)
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 2.2833 - mae: 2.2833
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0789 - mae: 2.0789
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0987 - mae: 2.0987
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9759 - mae: 1.9759
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0159 - mae: 2.0159
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9782 - mae: 1.9782
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9172 - mae: 1.9172
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9454 - mae: 1.9454
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9306 - mae: 1.9306
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9017 - mae: 1.9017
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6809 - mae: 1.6809
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6437 - mae: 1.6437
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6254 - mae: 1.6254
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5947 - mae: 1.5947
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5654 - mae: 1.5654
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5134 - mae: 1.5134
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5140 - mae: 1.5140
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5205 - mae: 1.5205
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4856 - mae: 1.4856
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4866 - mae: 1.4866
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4082 - mae: 1.4082
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4733 - mae: 1.4733
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4130 - mae: 1.4130
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4289 - mae: 1.4289
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4071 - mae: 1.4071
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3920 - mae: 1.3920
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4252 - mae: 1.4252
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3791 - mae: 1.3791
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3770 - mae: 1.3770
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3792 - mae: 1.3792
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3823 - mae: 1.3823
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3631 - mae: 1.3631
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3836 - mae: 1.3836
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3273 - mae: 1.3273
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3515 - mae: 1.3515
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3333 - mae: 1.3333
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3293 - mae: 1.3293
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3118 - mae: 1.3118
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2943 - mae: 1.2943
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3492 - mae: 1.3492
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3228 - mae: 1.3228
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3400 - mae: 1.3400
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3146 - mae: 1.3146
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2541 - mae: 1.2541
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2876 - mae: 1.2876
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2958 - mae: 1.2958
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2938 - mae: 1.2938
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3182 - mae: 1.3182
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3154 - mae: 1.3154
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2576 - mae: 1.2576
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2897 - mae: 1.2897
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2904 - mae: 1.2904
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2826 - mae: 1.2826
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2576 - mae: 1.2576
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2929 - mae: 1.2929
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.2440 - mae: 1.2440
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0357 - mae: 1.0357
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9972 - mae: 0.9972
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0085 - mae: 1.0085
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9835 - mae: 0.9835
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9967 - mae: 0.9967
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.0574 - mae: 1.0574
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.9744 - mae: 0.9744
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9494 - mae: 0.9494
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9668 - mae: 0.9668
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0256 - mae: 1.0256
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9515 - mae: 0.9515
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9500 - mae: 0.9500
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9765 - mae: 0.9765
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9523 - mae: 0.9523
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9413 - mae: 0.9413
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9458 - mae: 0.9458
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0388 - mae: 1.0388
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9470 - mae: 0.9470
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9834 - mae: 0.9834
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9666 - mae: 0.9666
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9750 - mae: 0.9750
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0054 - mae: 1.0054
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9297 - mae: 0.9297
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9412 - mae: 0.9412
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9460 - mae: 0.9460
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9069 - mae: 0.9069
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9055 - mae: 0.9055
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9234 - mae: 0.9234
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9040 - mae: 0.9040
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8858 - mae: 0.8858
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9227 - mae: 0.9227
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0901 - mae: 1.0901
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8982 - mae: 0.8982
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9304 - mae: 0.9304
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9142 - mae: 0.9142
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9288 - mae: 0.9288
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8949 - mae: 0.8949
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9279 - mae: 0.9279
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9071 - mae: 0.9071
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9095 - mae: 0.9095
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9192 - mae: 0.9192
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9122 - mae: 0.9122
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8865 - mae: 0.8865
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9068 - mae: 0.9068

# %%
model.evaluate(X_test, y_test)
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0388 - mae: 1.0388
# [1.0096173286437988, 1.0096173286437988]
