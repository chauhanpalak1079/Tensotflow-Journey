# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('/content/sample_data/placement.csv')

# %%
data.head(2)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                  26.0       1
# 1  7.46                  38.0       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   cgpa                  1000 non-null   float64
#  1   placement_exam_marks  1000 non-null   float64
#  2   placed                1000 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %%
X=data.drop(columns=['placed'])
X.head(2)
# Out:
#    cgpa  placement_exam_marks
# 0  7.19                  26.0
# 1  7.46                  38.0

# %%
y=data['placed']
y.head(2)
# Out:
# 0    1
# 1    1
# Name: placed, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=101)

# %%
X_train.shape
# Out:
# (750, 2)

# %%
tf.random.set_seed(55)

my_model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(90, activation='relu'),
    tf.keras.layers.Dense(50, activation= 'sigmoid'),
    tf.keras.layers.Dense(50, activation= 'sigmoid'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

my_model.compile( loss = tf.keras.losses.BinaryFocalCrossentropy,
                 optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001))

my_model.fit(X_train, y_train, epochs=100, verbose=1, validation_data=(X_test, y_test))
my_model.evaluate(X_test, y_test)
# Out:
# Epoch 1/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - loss: 0.2072 - val_loss: 0.1803
# Epoch 2/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1792 - val_loss: 0.1738
# Epoch 3/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1748 - val_loss: 0.1742
# Epoch 4/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1749 - val_loss: 0.1741
# Epoch 5/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.1746 - val_loss: 0.1740
# Epoch 6/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.1743 - val_loss: 0.1740
# Epoch 7/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.1741 - val_loss: 0.1740
# Epoch 8/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1740 - val_loss: 0.1740
# Epoch 9/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1739 - val_loss: 0.1741
# Epoch 10/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1739 - val_loss: 0.1741
# Epoch 11/100
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1738 - val_loss: 0.1741
# Epoch 12/100
# ...
